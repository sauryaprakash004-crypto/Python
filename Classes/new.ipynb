# %%
a=eval(input('enter:'))
def crow(t):
    e=set(t)
    f=list(e)
    return f
print(crow(a))
# Out:
# [1, 2, 3, 4, 5]

# %%
b=input('enter:')
def kill(n):
    g=[]
    for i in n.split('-'):
           g.append(i)
           e=sorted(g)
    for i in range(len(e)):
          if i==len(e)-1:
               print(e[i])
          else:
          
               print(e[i],end=('-'))
kill(b)
# Out:
# apple-cat-kill-zeb

# %%
a=input('enter:')
def count(g):
    c1=0
    c2=0
    for i in g:
        if 'A' <=i<='Z':
            c1=c1+1
        elif 'a'<=i<='z':
            c2=c2+1
    return c1,c2
print(count(a))
# Out:
# (4, 12)

# %%
a=int(input('enter:'))
def perfect(t):
    sum=0
    for i in range(1,t):
        if t%i==0:
            sum=sum+i
    if sum==t:
        return 'perfect'
    else:
        return 'not perfect'
print(perfect(a))
# Out:
# not perfect

# %%
a=int(input(''' 1.add more
             2.not add more'''))
if a==1:
    c=eval(input('enter dictionary:'))
else:
    print (c)
print(c)
# Out:
# {1: 2, 3: 4}

# %%
a=[13,42,15,37,22,39,41,50]

def monk(x):

# %%
def near(a,b):
    min=float('inf')
    for i in a:
        c=((i[0]-b[0])**2+(i[1]-b[1])**2)**0.5
        
        if c<=min:
            min=c
            d=i
    return min,f"{d} is close to {b}"
a=[(2,3),(3,5),(1,2),(4,5)]
b=(0,0)
print(near(a,b))
# Out:
# (2.23606797749979, '(1, 2) is close to (0, 0)')

# %%
d={}
e={}
while True:
    c=eval(input("enter the key and value"))
    d[c[0]]=c[1]
    flag=input("do you want to repeat(y/n)")
    if flag.lower()=='n':
        break
while True:
    c=eval(input("enter the key and value"))
    e[c[0]]=c[1]
    flag=input("do you want to repeat(y/n)")
    if flag.lower()=='n':
        break

def hell(d,e):
    return d|e
print(hell(d,e))
# Out:
# {1: 2, 3: 4, 5: 6}

# %%
x=[6,7,8,9,10]
print(list(map(filter i:i**2,x)))
# Out:
#   Cell In[35], line 2
#     print(list(map(filter i:i**2,x)))
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
y=lambda x,y:x+y
y('3','4')
# Out:
# '34'

# %%
a=2+5%3
print(a)
# Out:
# 4

# %%
a=[1,2]
b=[3,4]
a.extend(b)
c=sorted(a)
if len(c)%2==0:
            d=(c[len(c)//2]+c[(len(c)//2)-1])/2
else:
            d=c[(len(c)-1)//2]
print(d)
# Out:
# 2.5

# %%
s='hgfgf'
print(s[2])
# Out:
# f

# %%
s='aaaaba'
g={}
e={}
t=''
for i in range(0,len(s)):
    t=s[i]
    g[t]=len(t)
    for j in range(i+1,len(s)):
        t=t+s[j]
        g[t]=len(t)
    t=str()

    
for i in g.keys():
    if i[::]==i[::-1]:
        e[i]=len(i)
t=max(e.values())

for i in e.items():
    if i[1]==t:
        print(i[0])
# Out:
# aaaa

# %%
a=25
b=40
c=[]
d=[]
while a>1:
    for i in range(2,a):
        if a%i==0:
            a=a//i
            c.append(i)
            break
print(c)

# %%
print('helloworld')
# Out:
# helloworld

# %%
a=int(input('enter an integer:'))
if (a%4==0 and a%100!=0) or a%400==0:
    print(a,'is leap year')
else:
    print(a,'is not a leap year')
# Out:
# 2000 is leap year

# %%
passed=input('enter a password:')
b,c,d,e=0,0,0,0
for i in passed:
    if 'a' <=i<= 'z':
        b+=1
    elif 'A' <=i<= 'Z':
        c=+1
    elif '0' <=i<= '9':
        d=d+1
    elif i in '@#$':
        e=e+1
f=b+c+d+e
if (b>0 and c>0 and d>0 and e>0) and (f>=6 and f<=16):
    print('valid password')
else:
    print('invalid')
# Out:
# invalid
